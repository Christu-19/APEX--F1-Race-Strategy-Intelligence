# %%
import pandas as pd

race_results = pd.read_csv("../data/raw/race_results/british_gp_2025.csv")
q_results = pd.read_csv("../data/raw/qualifying/british_gp_2025.csv")
laps = pd.read_csv("../data/raw/laps/british_gp_2025.csv")
stints = pd.read_csv("../data/raw/stints/british_gp_2025.csv")
pit_stops = pd.read_csv("../data/raw/pit_stops/british_gp_2025.csv")
weather = pd.read_csv("../data/raw/weather/british_gp_2025.csv")

print("All six datasets loaded successfully!")
# Out:
# All six datasets loaded successfully!

# %%
datasets = {
    "RACE RESULTS": race_results,
    "QUALIFYING": q_results,
    "LAPS": laps,
    "STINTS": stints,
    "PIT STOPS": pit_stops,
    "WEATHER": weather
}

for name, df in datasets.items():
    print("\n" + "=" * 60)
    print(name)
    print("=" * 60)
    print(df.columns.tolist())
# Out:
# ...
# RACE RESULTS
# ...
# ['DriverNumber', 'BroadcastName', 'Abbreviation', 'DriverId', 'TeamName', 'TeamColor', 'TeamId', 'FirstName', 'LastName', 'FullName', 'HeadshotUrl', 'CountryCode', 'Position', 'ClassifiedPosition', 'GridPosition', 'Q1', 'Q2', 'Q3', 'Time', 'Status', 'Points', 'Laps']
#
# ...
# QUALIFYING
# ...
# ['DriverNumber', 'BroadcastName', 'Abbreviation', 'DriverId', 'TeamName', 'TeamColor', 'TeamId', 'FirstName', 'LastName', 'FullName', 'HeadshotUrl', 'CountryCode', 'Position', 'ClassifiedPosition', 'GridPosition', 'Q1', 'Q2', 'Q3', 'Time', 'Status', 'Points', 'Laps']
#
# ...
# LAPS
# ...

# %%
for name, df in datasets.items():
    print("\n"+ "="*60)
    print(name)
    print("="*60)
    print(df.isnull().sum())
# Out:
# ...
# RACE RESULTS
# ...
# DriverNumber           0
# BroadcastName          0
# Abbreviation           0
# DriverId               0
# TeamName               0
# TeamColor              0
# TeamId                 0
# FirstName              0
# LastName               0
# FullName               0
# HeadshotUrl            1
# CountryCode           20
# Position               0
# ClassifiedPosition     0
# GridPosition           0
# Q1                    20
# Q2                    20
# Q3                    20
# Time                   5
# Status                 0
# Points                 0
# Laps                   0
# dtype: int64
#
# ...
# QUALIFYING
# ...
# DriverNumber           0
# BroadcastName          0
# Abbreviation           0
# DriverId               0
# TeamName               0
# TeamColor              0
# TeamId                 0
# FirstName              0
# LastName               0
# FullName               0
# HeadshotUrl            1
# CountryCode           20
# Position               0
# ...

# %%
for name,df in datasets.items():
    print("\n"+"="*60)
    print(name)
    print(("="*60))
    print("Duplicated rows:",df.duplicated().sum())
# Out:
# ...
# RACE RESULTS
# ...
# Duplicated rows: 0
#
# ...
# QUALIFYING
# ...
# Duplicated rows: 0
#
# ...
# LAPS
# ...
# Duplicated rows: 0
#
# ...
# STINTS
# ...
# Duplicated rows: 0
#
# ...
# PIT STOPS
# ...
# Duplicated rows: 0
#
# ...
# WEATHER
# ...
# Duplicated rows: 0

# %%
for name,df in datasets.items():
    print("\n" + "="*60)
    print(name)
    print("="*60)
    print(df.head(4))
# Out:
# ...
# RACE RESULTS
# ...
#    DriverNumber BroadcastName Abbreviation    DriverId     TeamName TeamColor  \
# 0             4      L NORRIS          NOR      norris      McLaren    F47600
# 1            81     O PIASTRI          PIA     piastri      McLaren    F47600
# 2            27  N HULKENBERG          HUL  hulkenberg  Kick Sauber    01C00E
# 3            44    L HAMILTON          HAM    hamilton      Ferrari    ED1131
#
#     TeamId FirstName    LastName         FullName  ... Position  \
# 0  mclaren     Lando      Norris     Lando Norris  ...      1.0
# 1  mclaren     Oscar     Piastri    Oscar Piastri  ...      2.0
# 2   sauber      Nico  Hulkenberg  Nico Hulkenberg  ...      3.0
# 3  ferrari     Lewis    Hamilton   Lewis Hamilton  ...      4.0
#
#    ClassifiedPosition  GridPosition  Q1  Q2  Q3                    Time  \
# 0                   1           3.0 NaN NaN NaN  0 days 01:37:15.735000
# 1                   2           2.0 NaN NaN NaN  0 days 00:00:06.812000
# ...
